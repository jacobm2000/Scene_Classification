# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
df=pd.read_csv('./train.csv')
from tensorflow.keras import datasets, layers, models
import os
from os import listdir
from PIL import Image
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np
from tensorflow.keras import datasets, layers, models
import glob
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing import image
from sklearn.metrics import accuracy_score

# %%
 predList=[]
test=pd.read_csv('test.csv')
test=test[:150]

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in test.image_name:
        img = image.load_img("train/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        predList.append(pred.argmax())
        count+=1
        if(count==150):
            break
    test['labels '+str(modelName)]=predList

# %%
test
test.to_csv("test_results_t_prePro.csv")

# %%
test2=pd.read_csv('test_results_t_prePro(1).csv')
test2
# Out:
#      Unnamed: 0 image_name  UserClassification  Mode  labels InceptionPrePro  \
# 0             0      3.jpg                   5     5                       3
# 1             1      5.jpg                   0     0                       2
# 2             2      6.jpg                   4     4                       1
# 3             3     11.jpg                   2     2                       4
# 4             4     14.jpg                   5     5                       1
# ..          ...        ...                 ...   ...                     ...
# 145         145    494.jpg                   2     4                       1
# 146         146    497.jpg                   5     0                       0
# 147         147    498.jpg                   3     2                       0
# 148         148    499.jpg                   3     2                       0
# 149         149    507.jpg                   1     1                       3
#
#      labels ResNet50PrePro  labels vgg16PrePro  labels vgg19PrePro
# 0                        5                   5                   5
# 1                        0                   0                   0
# 2                        4                   4                   2
# 3                        3                   2                   2
# 4                        5                   5                   5
# ..                     ...                 ...                 ...
# 145                      5                   4                   4
# 146                      5                   5                   0
# 147                      2                   2                   2
# 148                      2                   2                   2
# 149                      1                   1                   1
#
# [150 rows x 8 columns]

# %%
acc=accuracy_score(test2['Mode'],test2['UserClassification'])
print( "Mode: " +str(acc))
for modelName in os.listdir('saved_model_t_prePro'):
        label='labels '+str(modelName)
        acc=accuracy_score(test2[label],test2['UserClassification'])
        print(modelName+ ": " +str(acc))
# Out:
# Mode: 0.6
# InceptionPrePro: 0.10666666666666667
# ResNet50PrePro: 0.6866666666666666
# vgg16PrePro: 0.6266666666666667
# vgg19PrePro: 0.54

# %%
test2 = test2[test2['UserClassification']!= 2]
test2 = test2[test2['UserClassification']!= 3]
test2
acc=accuracy_score(test2['Mode'],test2['UserClassification'])
for modelName in os.listdir('saved_model_t_prePro'):
        label='labels '+str(modelName)
        acc=accuracy_score(test2[label],test2['UserClassification'])
        print(modelName+ ": " +str(acc))
# Out:
# InceptionPrePro: 0.11363636363636363
# ResNet50PrePro: 0.875
# vgg16PrePro: 0.7613636363636364
# vgg19PrePro: 0.5795454545454546

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Buildings'):
        img = image.load_img("Buildings/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        predList.append(pred.argmax())
        count+=1
        if(count==29):
            break
    zeros=np.zeros(29)
    print(str(modelName)+ ": " + str(accuracy_score(zeros,predList)))
# Out:
# InceptionPrePro: 0.41379310344827586
# ResNet50PrePro: 0.8620689655172413
# vgg16PrePro: 0.7931034482758621
# vgg19PrePro: 0.9655172413793104

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Forest'):
        img = image.load_img("Forest/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        predList.append(pred.argmax())
        count+=1
        if(count==27):
            break
    ones=np.ones(27)
    print(str(modelName)+ ": " + str(accuracy_score(ones,predList)))
# Out:
# InceptionPrePro: 0.25925925925925924
# ResNet50PrePro: 0.8888888888888888
# vgg16PrePro: 0.8148148148148148
# vgg19PrePro: 0.7037037037037037

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Mountains'):
        img = image.load_img("Mountains/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        predList.append(pred.argmax())
        count+=1
        if(count==22):
            break
    twos=np.full((22),2)
    print(str(modelName)+ ": " + str(accuracy_score(twos,predList)))
# Out:
# InceptionPrePro: 0.09090909090909091
# ResNet50PrePro: 0.22727272727272727
# vgg16PrePro: 0.5
# vgg19PrePro: 0.3181818181818182

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Glacier'):
        img = image.load_img("Glacier/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        predList.append(pred.argmax())
        count+=1
        if(count==25):
            break
    threes=np.full((25),2)
    print(str(modelName)+ ": " + str(accuracy_score(threes,predList)))
# Out:
# InceptionPrePro: 0.12
# ResNet50PrePro: 0.44
# vgg16PrePro: 0.84
# vgg19PrePro: 0.88

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Mountains'):
        img = image.load_img("Mountains/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        if(pred.argmax()==3 or pred.argmax()==2):
            predList.append(3)
        else:
            predList.append(pred.argmax())
        count+=1
        if(count==22):
            break
    threes=np.full((22),3)
    print(str(modelName)+ ": " + str(accuracy_score(threes,predList)))
# Out:
# InceptionPrePro: 0.18181818181818182
# ResNet50PrePro: 0.7272727272727273
# vgg16PrePro: 0.8636363636363636
# vgg19PrePro: 0.7727272727272727

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Sea'):
        img = image.load_img("Sea/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        predList.append(pred.argmax())
        count+=1
        if(count==27):
            break
    fours=np.full((27),4)
    print(str(modelName)+ ": " + str(accuracy_score(fours,predList)))
# Out:
# InceptionPrePro: 0.07407407407407407
# ResNet50PrePro: 0.7037037037037037
# vgg16PrePro: 0.37037037037037035
# vgg19PrePro: 0.2962962962962963

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Street'):
        img = image.load_img("Street/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        predList.append(pred.argmax())
        count+=1
        if(count==28):
            break
    fives=np.full((28),5)
    print(str(modelName)+ ": " + str(accuracy_score(fives,predList)))
# Out:
# InceptionPrePro: 0.0
# ResNet50PrePro: 0.7857142857142857
# vgg16PrePro: 0.7142857142857143
# vgg19PrePro: 0.10714285714285714

# %%
for modelName in os.listdir('saved_model_t_prePro'):
    predList=[]
    count=0
    model=models.load_model('saved_model_t_prePro/'+str(modelName))
    for filename in os.listdir('Street'):
        img = image.load_img("Street/" +str(filename), target_size=(150, 150))
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        pred=model.predict(x)
        if(pred.argmax()==0 or pred.argmax()==5):
            predList.append(5)
        else:
            predList.append(pred.argmax())
        count+=1
        if(count==28):
            break
    fives=np.full((28),5)
    print(str(modelName)+ ": " + str(accuracy_score(fives,predList)))
# Out:
# InceptionPrePro: 0.42857142857142855
# ResNet50PrePro: 0.8928571428571429
# vgg16PrePro: 0.7857142857142857
# vgg19PrePro: 0.9285714285714286

# %%
test2=pd.read_csv('test_results_t_prePro(1).csv')
test2
test2['UserClassification'].replace(5,0,inplace=True)
test2['UserClassification'].replace(3,2,inplace=True)
test2['Mode'].replace(3,2,inplace=True)
test2['Mode'].replace(5,0,inplace=True)
for modelName in os.listdir('saved_model_t_prePro'):
        label='labels '+str(modelName)
        test2[label].replace(3,2,inplace=True)
        test2[label].replace(5,0,inplace=True)
test2[:50]
# Out:
#     Unnamed: 0 image_name  UserClassification  Mode  labels InceptionPrePro  \
# 0            0      3.jpg                   0     0                       2
# 1            1      5.jpg                   0     0                       2
# 2            2      6.jpg                   4     4                       1
# 3            3     11.jpg                   2     2                       4
# 4            4     14.jpg                   0     0                       1
# 5            5     22.jpg                   1     1                       0
# 6            6     25.jpg                   4     4                       2
# 7            7     28.jpg                   2     2                       1
# 8            8     30.jpg                   2     2                       0
# 9            9     38.jpg                   2     2                       1
# 10          10     51.jpg                   2     2                       1
# 11          11     52.jpg                   2     2                       1
# 12          12     61.jpg                   0     0                       1
# 13          13     63.jpg                   4     4                       4
# 14          14     64.jpg                   1     1                       2
# 15          15     69.jpg                   0     0                       1
# 16          16     70.jpg                   2     2                       1
# 17          17     72.jpg                   0     0                       2
# 18          18     73.jpg                   0     0                       1
# 19          19     76.jpg                   2     2                       1
# 20          20     77.jpg                   0    -1                       0
# 21          21     79.jpg                   0     4                       4
# 22          22     81.jpg                   2     2                       1
# 23          23     84.jpg                   2     2                       1
# 24          24     88.jpg                   1     1                       4
# 25          25     93.jpg                   0     0                       1
# 26          26     99.jpg                   1     1                       2
# 27          27    101.jpg                   2     2                       1
# 28          28    103.jpg                   0     0                       1
# 29          29    110.jpg                   2     4                       4
# 30          30    117.jpg                   2     2                       2
# 31          31    119.jpg                   2     2                       1
# 32          32    121.jpg                   0     0                       0
# 33          33    126.jpg                   0     0                       2
# 34          34    127.jpg                   2     2                       1
# 35          35    129.jpg                   4     4                       2
# 36          36    130.jpg                   4     2                       1
# 37          37    132.jpg                   4     2                       0
# 38          38    133.jpg                   0     0                       0
# 39          39    135.jpg                   4     4                       1
# 40          40    140.jpg                   0     0                       0
# 41          41    141.jpg                   0     0                       1
# 42          42    143.jpg                   2     2                       4
# 43          43    144.jpg                   0     0                       1
# 44          44    145.jpg                   0     0                       2
# 45          45    149.jpg                   1     1                       2
# 46          46    152.jpg                   1     1                       2
# 47          47    156.jpg                   0     0                       2
# 48          48    161.jpg                   4     4                       1
# 49          49    169.jpg                   0     0                       1
#
#     labels ResNet50PrePro  labels vgg16PrePro  labels vgg19PrePro
# 0                       0                   0                   0
# 1                       0                   0                   0
# 2                       4                   4                   2
# 3                       2                   2                   2
# 4                       0                   0                   0
# 5                       1                   1                   1
# 6                       4                   4                   0
# 7                       2                   2                   2
# 8                       2                   2                   2
# 9                       2                   2                   2
# 10                      2                   2                   2
# 11                      2                   2                   2
# 12                      0                   0                   0
# 13                      4                   1                   0
# 14                      1                   1                   1
# 15                      0                   0                   0
# 16                      2                   2                   2
# 17                      0                   0                   0
# 18                      0                   0                   0
# 19                      2                   2                   2
# 20                      2                   2                   1
# 21                      0                   4                   0
# 22                      2                   2                   2
# 23                      2                   2                   2
# 24                      1                   1                   1
# 25                      0                   0                   0
# 26                      1                   1                   1
# 27                      2                   2                   2
# 28                      0                   0                   0
# 29                      4                   2                   2
# 30                      2                   2                   4
# 31                      2                   2                   2
# 32                      0                   0                   0
# 33                      0                   0                   0
# 34                      2                   2                   2
# 35                      4                   4                   4
# 36                      2                   2                   2
# 37                      2                   2                   4
# 38                      0                   0                   0
# 39                      4                   4                   0
# 40                      0                   0                   0
# 41                      0                   0                   0
# 42                      2                   2                   2
# 43                      0                   0                   0
# 44                      0                   0                   0
# 45                      1                   1                   1
# 46                      1                   1                   1
# 47                      0                   0                   0
# 48                      4                   4                   4
# 49                      0                   0                   0

# %%
acc=accuracy_score(test2['Mode'],test2['UserClassification'])
print( "Mode: " +str(acc))
modelnames=[]
alpha="abcdefghijklmnopqrstuvwxyz"
accuracy=[]
count=0
for modelName in os.listdir('saved_model_t_prePro'):
        label='labels '+str(modelName)
        acc=accuracy_score(test2[label],test2['UserClassification'])
        print(str(alpha[count])+" " +str(modelName)+ ": " +str(acc))
        modelnames.append(alpha[count])
        accuracy.append(acc)
        count+=1
# Out:
# Mode: 0.8533333333333334
# a InceptionPrePro: 0.2
# b ResNet50PrePro: 0.8866666666666667
# c vgg16PrePro: 0.8666666666666667
# d vgg19PrePro: 0.82

# %%
plt.bar(modelnames, accuracy, color ='maroon',
        width = 0.4)
plt.show()
